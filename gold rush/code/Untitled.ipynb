# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/low-pass.csv", sep=";", comment="#")

# %%
freq_n, voltage_n = df
df = df.sort_values(freq_n)
freq, voltage = df[freq_n], df[voltage_n]
freq *= 1e3
voltage/=3

# %%
C = 0.22e-6
R = 1e3

ω = np.arange(min(freq), max(freq), 1) * 2*np.pi
theory = 1/(R**2*(ω**2*C**2) + 1)**0.5

# %%
# %matplotlib widget
plt.loglog()
plt.grid(ls='--', c='0.8')
plt.scatter(freq, voltage*2**0.5, s=6, label="Эксперимент")
plt.plot(ω/2/np.pi, theory, label="Теория")
plt.xlabel("Частота сигнала, Гц")
plt.ylabel("Доля пропускаемого сигнала")
plt.legend()
plt.savefig("../img/FR_lowpass_sqrt2.png", dpi=300)

pass
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1/2**0.5
# Out:
# 0.7071067811865475
